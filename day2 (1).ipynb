# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/titanic uncleaned.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail(6)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 412         1304         1       3  Henriksson, Miss. Jenny Lovisa  female
# 413         1305         0       3              Spector, Mr. Woolf    male
# 414         1306         1       1    Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3    Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3             Ware, Mr. Frederick    male
# 417         1309         0       3        Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 412  28.0      0      0              347086    7.7750   NaN        S
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# ...

# %%
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.shape
# Out:
# (418, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['age_mean']=df['Age'].fillna(df['Age'].mean())
df['age_median']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  age_mean  age_median
# 0   330911   7.8292   NaN        Q      34.5        34.5
# 1   363272   7.0000   NaN        S      47.0        47.0
# 2   240276   9.6875   NaN        Q      62.0        62.0
# 3   315154   8.6625   NaN        S      27.0        27.0
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False  False  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False  False  False  False   False
# 417        False     False   False  False  False  False  False  False   False
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  age_mean  age_median
# 0   330911   7.8292   NaN        Q      34.5        34.5
# 1   363272   7.0000   NaN        S      47.0        47.0
# 2   240276   9.6875   NaN        Q      62.0        62.0
# 3   315154   8.6625   NaN        S      27.0        27.0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df[['Age','age_mean']]
# Out:
#           Age  age_mean
# 0    34.50000  34.50000
# 1    47.00000  47.00000
# 2    62.00000  62.00000
# 3    27.00000  27.00000
# 4    22.00000  22.00000
# ..        ...       ...
# 413  30.27259  30.27259
# 414  39.00000  39.00000
# 415  38.50000  38.50000
# 416  30.27259  30.27259
# 417  30.27259  30.27259
#
# [418 rows x 2 columns]

# %%
df.head(13)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

sns.set(style="dark")

plt.figure(figsize=(10,6))

sns.boxplot(data=df,x='Embarked',y='Fare',palette='bright')
#set plot title and label

plt.title('Box plot of embarked by fare',fontsize=15)
plt.xlabel('Embarked',fontsize=12)
plt.ylabel('Fare',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_1316/335772159.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Embarked',y='Fare',palette='bright')

# %%
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(10,6))

sns.lineplot(data=df,x='Embarked',y='Fare',palette='pastel')
#set plot title and label

plt.title('Box plot of embarked by fare',fontsize=15)
plt.xlabel('Embarked',fontsize=12)
plt.ylabel('Fare',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_1316/606957429.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df,x='Embarked',y='Fare',palette='pastel')

# %%
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(10,6))

sns.barplot(data=df,x='Embarked',y='Fare',palette='pastel')
#set plot title and label

plt.title('Box plot of embarked by fare',fontsize=15)
plt.xlabel('Embarked',fontsize=12)
plt.ylabel('Fare',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_1316/226218850.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='Embarked',y='Fare',palette='pastel')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoded_data=df.copy()

# %%
one_hot_encoded = pd.get_dummies(encoded_data['Embarked'], prefix='Embarked')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)

# Since 'Pclass' is ordinal, we can create a mapped column for demonstration.
pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}
# 3. Ordinal Encoding For p class
encoded_data['Pclass_Category'] = encoded_data['Pclass'].map(pclass_mapping)

# Display the resulting dataset with relevant encoded columns
print(encoded_data[['Sex', 'Embarked', 'Embarked_Q', 'Embarked_S', 'Embarked_C', 'Pclass', 'Pclass_Category']].head())
# Out:
#       Sex Embarked  Embarked_Q  Embarked_S  Embarked_C  Pclass Pclass_Category
# 0    male        Q        True       False       False       3           Third
# 1  female        S       False        True       False       3           Third
# 2    male        Q        True       False       False       2          Second
# 3    male        S       False        True       False       3           Third
# 4  female        S       False        True       False       3           Third

# %% [markdown]
# # day 2

# %%
import pandas as pd
#skikitlearn
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler

# %%
titanic_data=pd.read_csv("/content/titanic uncleaned.csv")


#nnumerical columns
numerical_col=['Age','Fare','Pclass']

#drop rows with missing values
titanic_data.dropna(subset=numerical_col,inplace=True)

#initilize scalers
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
robust_scaler=RobustScaler()


#applying minmax scaling
titanic_data['Age_minmax']=minmax_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_minmax']=minmax_scaler.fit_transform(titanic_data[['Fare']])


#apply standard scaling

titanic_data['Age_standard']=standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_standard']=standard_scaler.fit_transform(titanic_data[['Fare']])


#apply robust scaling

titanic_data['Age_robust']=robust_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_robust']=robust_scaler.fit_transform(titanic_data[['Fare']])
titanic_data[['Age','Age_minmax','Fare_minmax','Age_standard','Fare_standard','Age_robust','Fare_standard']]
# Out:
#       Age  Age_minmax  Fare_minmax  Age_standard  Fare_standard  Age_robust  \
# 0    34.5    0.452723     0.015282      0.306657      -0.542281    0.416667
# 1    47.0    0.617566     0.013663      1.194236      -0.555844    1.111111
# 2    62.0    0.815377     0.018909      2.259331      -0.511885    1.944444
# 3    27.0    0.353818     0.016908     -0.225890      -0.528651    0.000000
# 4    22.0    0.287881     0.023984     -0.580922      -0.469357   -0.277778
# ..    ...         ...          ...           ...            ...         ...
# 409   3.0    0.037320     0.026887     -1.930042      -0.445026   -1.333333
# 411  37.0    0.485692     0.175668      0.484173       0.801785    0.555556
# 412  28.0    0.367005     0.015176     -0.154884      -0.543168    0.055556
# 414  39.0    0.512066     0.212559      0.626186       1.110932    0.666667
# 415  38.5    0.505473     0.014151      0.590683      -0.551755    0.638889
#
#      Fare_standard
# 0        -0.542281
# ...

# %% [markdown]
# encoding

# %%
import pandas as pd

dp=pd.read_csv("/content/preprocessing_practice_dataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder

encoded_data=dp.copy()

one_hot_encoded = pd.get_dummies(encoded_data['Education'], prefix='Education')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)

# Since 'Pclass' is ordinal, we can create a mapped column for demonstration.
education_mapping = {1: 'Masters', 2: 'Bachelors', 3: 'phD'}
# 3. Ordinal Encoding For p class
encoded_data['education_Category'] = encoded_data['Education'].map(education_mapping)

# Display the resulting dataset with relevant encoded columns
print(encoded_data[['Gender', 'Department', 'Education', 'Education_Masters', 'Education_Bachelors', 'Education_PhD', 'City']].head())
# Out:
#    Gender Department  Education  Education_Masters  Education_Bachelors  \
# 0    Male         HR    Masters               True                False
# 1  Female  Marketing  Bachelors              False                 True
# 2  Female         HR        NaN              False                False
# 3  Female         HR        PhD              False                False
# 4    Male         IT  Bachelors              False                 True
#
#    Education_PhD        City
# 0          False     Calicut
# 1          False     Chennai
# 2          False       Kochi
# 3           True  Trivandrum
# 4          False  Trivandrum

# %% [markdown]
# scaling

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="whitegrid")

plt.figure(figsize=(18,8))

sns.barplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Bar plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_1316/1896398453.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="whitegrid")

plt.figure(figsize=(18,8))

sns.boxplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Box plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_1316/3248758682.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="whitegrid")

plt.figure(figsize=(18,8))

sns.histplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('Histogram plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_1316/2364895224.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %%
import matplotlib.pyplot as plt
dd=pd.read_csv("/content/preprocessing_practice_dataset.csv")
sns.set(style="dark")

plt.figure(figsize=(18,8))

sns.scatterplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
#set plot title and label

plt.title('scatter plot of age by experience_years',fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Experience_years',fontsize=12)
# Out:
# /tmp/ipykernel_1316/621493887.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=dd,x='Age',y='Experience_Years',palette='pastel')
# Text(0, 0.5, 'Experience_years')

# %% [markdown]
# SCALING

# %%
import pandas as pd
#skikitlearn
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler

# %%
practice_data=pd.read_csv("/content/preprocessing_practice_dataset.csv")


#nnumerical columns
numerical_col=['Age','Performance_Rating']

#drop rows with missing values
practice_data.dropna(subset=numerical_col,inplace=True)

#initilize scalers
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
robust_scaler=RobustScaler()


#applying minmax scaling
practice_data['Age_minmax']=minmax_scaler.fit_transform(practice_data[['Age']])
practice_data['perfomance_minmax']=minmax_scaler.fit_transform(practice_data[['Performance_Rating']])


#apply standard scaling

practice_data['Age_standard']=standard_scaler.fit_transform(practice_data[['Age']])
practice_data['perfomance_standard']=standard_scaler.fit_transform(practice_data[['Performance_Rating']])


#apply robust scaling

practice_data['Age_robust']=robust_scaler.fit_transform(practice_data[['Age']])
practice_data['perfomance_robust']=robust_scaler.fit_transform(practice_data[['Performance_Rating']])
practice_data[['Age','Age_minmax','perfomance_minmax','Age_standard','perfomance_standard','Age_robust','perfomance_standard']]
# Out:
#      Age  Age_minmax  perfomance_minmax  Age_standard  perfomance_standard  \
# 0   59.0    1.000000               1.00      1.746756             1.178954
# 1   49.0    0.736842               0.25      0.833817            -0.874708
# 2   35.0    0.368421               0.00     -0.444297            -1.559262
# 3   28.0    0.184211               0.25     -1.083354            -0.874708
# 4   41.0    0.526316               0.50      0.103466            -0.190154
# ..   ...         ...                ...           ...                  ...
# 95  54.0    0.868421               1.00      1.290286             1.178954
# 96  53.0    0.842105               1.00      1.198993             1.178954
# 97  43.0    0.578947               0.50      0.286054            -0.190154
# 98  44.0    0.605263               1.00      0.377348             1.178954
# 99  57.0    0.947368               0.25      1.564168            -0.874708
#
#     Age_robust  perfomance_standard
# ...
